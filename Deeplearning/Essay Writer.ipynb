# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List
import operator
from langgraph.checkpoint.sqlite import SqliteSaver
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage

#memory = SqliteSaver.from_conn_string(":memory:")

# %%
class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
PLAN_PROMPT = """You are an expert writer tasked with writing a high level outline of an essay. \
Write such an outline for the user provided topic. Give an outline of the essay along with any relevant notes \
or instructions for the sections."""

# %%
WRITER_PROMPT = """You are an essay assistant tasked with writing excellent 5-paragraph essays.\
Generate the best essay possible for the user's request and the initial outline. \
If the user provides critique, respond with a revised version of your previous attempts. \
Utilize all the information below as needed: 

------

{content}"""

# %%
REFLECTION_PROMPT = """You are a teacher grading an essay submission. \
Generate critique and recommendations for the user's submission. \
Provide detailed recommendations, including requests for length, depth, style, etc."""

# %%
RESEARCH_PLAN_PROMPT = """You are a researcher charged with providing information that can \
be used when writing the following essay. Generate a list of search queries that will gather \
any relevant information. Only generate 3 queries max."""

# %%
RESEARCH_CRITIQUE_PROMPT = """You are a researcher charged with providing information that can \
be used when making any requested revisions (as outlined below). \
Generate a list of search queries that will gather any relevant information. Only generate 3 queries max."""

# %%
from pydantic import BaseModel

class Queries(BaseModel):
    queries: List[str]

# %%
from tavily import TavilyClient
import os
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT), 
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state.get('content', [])
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
        ]
    response = model.invoke(messages)
    return {
        "draft": response.content, 
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT), 
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state.get('content', [])
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

# %%
builder.set_entry_point("planner")

# %%
builder.add_conditional_edges(
    "generate", 
    should_continue, 
    {END: END, "reflect": "reflect"}
)

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
with SqliteSaver.from_conn_string(":memory:") as memory:
    graph = builder.compile(checkpointer=memory)

    from IPython.display import Image

    Image(graph.get_graph().draw_png())

    thread = {"configurable": {"thread_id": "1"}}
    for s in graph.stream({
        'task': "what is the difference between langchain and langsmith",
        "max_revisions": 2,
        "revision_number": 1,
    }, thread):
        print(s)
# Out:
# {'planner': {'plan': 'I. Introduction\n    A. Brief overview of Langchain and Langsmith\n    B. Thesis statement: Exploring the differences between Langchain and Langsmith\n\nII. Langchain\n    A. Definition and explanation\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and disadvantages\n\nIII. Langsmith\n    A. Definition and explanation\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and disadvantages\n\nIV. Comparison between Langchain and Langsmith\n    A. Technology stack\n    B. Scalability\n    C. Security\n    D. Interoperability\n    E. Performance\n\nV. Conclusion\n    A. Recap of main differences between Langchain and Langsmith\n    B. Implications for future development and adoption\n    C. Final thoughts on the significance of these technologies\n\nNotes:\n- Ensure to provide clear definitions and explanations of both Langchain and Langsmith.\n- Include specific examples of use cases and applications for each technology.\n- Use comparative analysis to highlight the distinctions between Langchain and Langsmith.\n- Conclude with insights on the potential impact and future prospects of these technologies.'}}
# /Users/sarathv/envforlanggraph/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:2210: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(
# {'research_plan': {'content': ["LangChain is a framework for building applications, while LangSmith is a platform for debugging, evaluating, deploying, and monitoring them.*. LangChain became a leading framework for orchestrating LLM workflows, while LangSmith followed to fill important gaps in debugging, evaluation, and production readiness. LangSmith\xa0is a platform for developing, debugging, evaluating, deploying, and monitoring LLM applications. LangSmith provides tools for **tracing requests, evaluating outputs, testing prompts, and managing deployments**\xa0in one place. **LangSmith is a development and deployment platform.** It observes your application through tracing, provides evaluation tools, and hosts your deployments. ## When to Use LangChain or LangSmith. **Can you use LangSmith without LangChain?**. **Does LangSmith work with frameworks other than LangChain?**. Manual instrumentation requires more code than LangChain's automatic tracing, but you get the same observability, evaluation, and deployment features. **Do I need both LangChain AND LangSmith for production?**. You can use LangChain without LangSmith by implementing your own logging and monitoring. You can use LangSmith without LangChain by manually instrumenting your application.", 'If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', '* [Overview](/oss/python/langchain/overview). * [Install](/oss/python/langchain/install). * [Quickstart](/oss/python/langchain/quickstart). * [Philosophy](/oss/python/langchain/philosophy). * [Agents](/oss/python/langchain/agents). * [Models](/oss/python/langchain/models). * [Messages](/oss/python/langchain/messages). * [Tools](/oss/python/langchain/tools). * [Streaming](/oss/python/langchain/streaming). * [Overview](/oss/python/langchain/middleware/overview). * [Prebuilt middleware](/oss/python/langchain/middleware/built-in). * [Overview](/oss/python/langchain/frontend/overview). * [Runtime](/oss/python/langchain/runtime). * [Model Context Protocol (MCP)](/oss/python/langchain/mcp). * [Retrieval](/oss/python/langchain/retrieval). * [LangSmith Studio](/oss/python/langchain/studio). * [Agent Chat UI](/oss/python/langchain/ui). * [Deployment](/oss/python/langchain/deploy). * [Observability](/oss/python/langchain/observability). LangChain is the easy way to start building completely custom agents and applications powered by LLMs. With under 10 lines of code, you can connect to OpenAI, Anthropic, Google, and [more](/oss/python/integrations/providers/overview). If you don’t need these capabilities or would like to customize your own for your agents and autonomous applications, start with LangChain.Use [LangGraph](/oss/python/langgraph/overview), our low-level agent orchestration framework and runtime, when you have more advanced needs that require a combination of deterministic and agentic workflows and heavy customization. LangChain [agents](/oss/python/langchain/agen ...
# {'generate': {'draft': "**Essay:**\n\n**I. Introduction**\n\nLangChain and LangSmith are two essential tools in the realm of AI development and deployment. While both serve crucial roles in the lifecycle of AI applications, they cater to distinct needs and functions. This essay aims to delve into the disparities between LangChain and LangSmith, shedding light on their unique features and applications.\n\n**II. LangChain**\n\nLangChain is a framework tailored for constructing applications based on large language models (LLMs). It simplifies the process of developing data-responsive applications by streamlining intermediate steps. Developers leverage LangChain to connect language models with external data sources, enabling flexibility in adapting models to specific business contexts. With tools like LangChain Expression Language (LCEL), developers can compose chains effortlessly, creating prompt templates for chatbots, few-shot learning, and more. While LangChain excels in prompt engineering and customization, it may require more manual intervention for certain tasks.\n\n**III. LangSmith**\n\nIn contrast, LangSmith serves as a platform for debugging, evaluating, deploying, and monitoring LLM applications. It offers a comprehensive suite of tools for tracing requests, evaluating outputs, testing prompts, and managing deployments within a unified environment. LangSmith's focus lies in providing observability and control over AI systems in production, making it indispensable for debugging complex models and orchestrating large-scale workflows. Its advanced architecture caters to the needs of intricate AI pipelines and extensive monitoring requirements.\n\n**IV. Comparison between LangChain and LangSmith**\n\n- **Technology Stack:** LangChain is primarily geared towards building applications, while LangSmith is dedicated to debugging and monitoring those applications.\n- **Scalability:** LangChain excels in managing and scaling model workflows, whereas LangSmith offers deep visibility and control over complex AI systems in production.\n- **Security:** Both LangChain and LangSmith prioritize security, but LangSmith's observability features enhance security by enabling thorough monitoring and debugging.\n- **Interoperability:** LangChain can be used without LangSmith by implementing custom logging and monitoring, while LangSmith can function independently by manual instrumentation.\n- **Performance:** LangChain streamlines prompt engineering and application development, while LangSmith enhances performance through advanced debugging and orchestration features.\n\n**V. Conclusion**\n\nIn conclusion, the disparities between LangChain and LangSmith underscore their complementary roles in the AI development landscape. Understanding the distinct features, applications, and advantages of each tool is crucial for leveraging them effectively in different scenarios. As AI technologies continue to evolve, the significance of tools like LangChain and LangSmith in enhancing productivity, performance, and observability cannot be overstated. Embracing these technologies judiciously based on project requirements is key to unlocking their full potential and driving innovation in the AI domain.", 'revision_number': 2}}
# {'reflect': {'critique': "**Critique:**\n\nThe essay provides a clear overview of LangChain and LangSmith, highlighting their key features and differences effectively. The introduction sets the stage well by outlining the purpose of the essay, and the subsequent sections delve into each tool's functionalities in a structured manner. The comparison section offers a concise breakdown of how LangChain and LangSmith differ in terms of technology stack, scalability, security, interoperability, and performance.\n\n**Recommendations:**\n\n1. **Depth and Detail:** While the essay covers the basics of LangChain and LangSmith, consider expanding on specific examples or case studies to illustrate how these tools are used in real-world scenarios. Providing concrete instances can help readers grasp the practical applications and benefits of each tool more effectively.\n\n2. **Explanation of Technical Terms:** When discussing technical aspects like LangChain Expression Language (LCEL) or advanced debugging features, ensure that you provide a brief explanation or example to help readers who may not be familiar with these terms understand their significance.\n\n3. **Additional Comparison Points:** To enhance the comparison between LangChain and LangSmith, consider adding more nuanced differences or similarities between the two tools. For instance, you could explore how they handle data privacy, integration with other AI frameworks, or support for different programming languages.\n\n4. **Conclusion:** While the conclusion summarizes the main points effectively, consider reinforcing the importance of choosing the right tool based on specific project requirements. Emphasize the impact that selecting the appropriate tool can have on the success of AI projects and the overall efficiency of development and deployment processes.\n\n5. **Length:** The essay could benefit from expanding on each tool's features and functionalities to provide a more comprehensive understanding for readers. Aim to elaborate on specific use cases, challenges addressed by each tool, and potential future developments in the field of AI development and deployment.\n\nOverall, the essay presents a solid foundation for comparing LangChain and LangSmith. By incorporating more depth, examples, and nuanced comparisons, you can enrich the content and provide readers with a more insightful analysis of these essential AI tools."}}
# /Users/sarathv/envforlanggraph/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:2210: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(
# {'research_critique': {'content': ["LangChain is a framework for building applications, while LangSmith is a platform for debugging, evaluating, deploying, and monitoring them.*. LangChain became a leading framework for orchestrating LLM workflows, while LangSmith followed to fill important gaps in debugging, evaluation, and production readiness. LangSmith\xa0is a platform for developing, debugging, evaluating, deploying, and monitoring LLM applications. LangSmith provides tools for **tracing requests, evaluating outputs, testing prompts, and managing deployments**\xa0in one place. **LangSmith is a development and deployment platform.** It observes your application through tracing, provides evaluation tools, and hosts your deployments. ## When to Use LangChain or LangSmith. **Can you use LangSmith without LangChain?**. **Does LangSmith work with frameworks other than LangChain?**. Manual instrumentation requires more code than LangChain's automatic tracing, but you get the same observability, evaluation, and deployment features. **Do I need both LangChain AND LangSmith for production?**. You can use LangChain without LangSmith by implementing your own logging and monitoring. You can use LangSmith without LangChain by manually instrumenting your application.", 'If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', '* [Overview](/oss/python/langchain/overview). * [Install](/oss/python/langchain/install). * [Quickstart](/oss/python/langchain/quickstart). * [Philosophy](/oss/python/langchain/philosophy). * [Agents](/oss/python/langchain/agents). * [Models](/oss/python/langchain/models). * [Messages](/oss/python/langchain/messages). * [Tools](/oss/python/langchain/tools). * [Streaming](/oss/python/langchain/streaming). * [Overview](/oss/python/langchain/middleware/overview). * [Prebuilt middleware](/oss/python/langchain/middleware/built-in). * [Overview](/oss/python/langchain/frontend/overview). * [Runtime](/oss/python/langchain/runtime). * [Model Context Protocol (MCP)](/oss/python/langchain/mcp). * [Retrieval](/oss/python/langchain/retrieval). * [LangSmith Studio](/oss/python/langchain/studio). * [Agent Chat UI](/oss/python/langchain/ui). * [Deployment](/oss/python/langchain/deploy). * [Observability](/oss/python/langchain/observability). LangChain is the easy way to start building completely custom agents and applications powered by LLMs. With under 10 lines of code, you can connect to OpenAI, Anthropic, Google, and [more](/oss/python/integrations/providers/overview). If you don’t need these capabilities or would like to customize your own for your agents and autonomous applications, start with LangChain.Use [LangGraph](/oss/python/langgraph/overview), our low-level agent orchestration framework and runtime, when you have more advanced needs that require a combination of deterministic and agentic workflows and heavy customization. LangChain [agents](/oss/python/langchain/ ...
# {'generate': {'draft': "**Essay:**\n\nI. **Introduction**\n\nLangChain and LangSmith are two essential tools in the realm of developing and managing applications based on large language models (LLMs). LangChain serves as a framework for building applications, while LangSmith functions as a platform for debugging, evaluating, deploying, and monitoring these applications. This essay aims to delve into the disparities between LangChain and LangSmith to provide a comprehensive understanding of their unique functionalities and applications.\n\nII. **LangChain**\n\nLangChain is an open-source framework tailored for constructing applications utilizing large language models. It streamlines the process of developing data-responsive applications by simplifying prompt engineering and connecting language models with external data sources. Developers leverage LangChain to customize prompt chains, build chatbot applications, enable few-shot learning, and provide specific instructions to language models. While LangChain offers flexibility and efficiency in application development, it may require manual monitoring and logging when used independently.\n\nIII. **LangSmith**\n\nIn contrast, LangSmith is a platform designed for developing, debugging, evaluating, deploying, and monitoring LLM applications. It provides comprehensive tools for tracing requests, evaluating outputs, testing prompts, and managing deployments within a unified platform. LangSmith's focus on observability and performance optimization makes it an indispensable tool for ensuring the seamless operation of AI models in production environments.\n\nIV. **Comparison between LangChain and LangSmith**\n\nA. **Technology Stack**: LangChain primarily focuses on building applications powered by LLMs, while LangSmith emphasizes observability and deployment. \nB. **Scalability**: LangChain excels in managing and scaling model workflows, whereas LangSmith offers deep visibility and control over complex AI systems in production.\nC. **Security**: Both LangChain and LangSmith prioritize security, but LangSmith's monitoring capabilities enhance security by providing insights into application behavior.\nD. **Interoperability**: LangChain can be used without LangSmith by implementing custom monitoring, while LangSmith can function independently by manual instrumentation.\nE. **Performance**: LangChain streamlines application development, while LangSmith enhances performance through tracing, monitoring, and evaluation tools.\n\nV. **Conclusion**\n\nIn conclusion, LangChain and LangSmith cater to distinct aspects of application development and management in the realm of LLMs. Understanding the differences between these tools is crucial for choosing the right technology based on project requirements. While LangChain simplifies application building, LangSmith offers advanced observability and deployment features. The future adoption of these technologies will depend on the evolving needs of developers and the complexity of AI applications.\n\nBy exploring the nuances between LangChain and LangSmith, developers can make informed decisions to optimize their workflow and enhance the performance of their AI applications.", 'revision_number': 3}}

# %%
#Essay Writer Interface

import warnings
warnings.filterwarnings("ignore")

from helper import ewriter, writer_gui

MultiAgent = ewriter()
app = writer_gui(MultiAgent.graph)
app.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
